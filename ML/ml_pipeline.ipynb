# %% [markdown]
# <h1 align="center">MSIN0114: Business Analytics Consulting Project</h1>
# <h2 align="center">S2R Analytics</h2>

# %% [markdown]
# # Table of Contents
#
# **Predictive analytics (ML pipeline)**
#
# * [Part 3](#part3): Exploratory data analysis
# <br />
# <br />
# * [Part 4](#part4): Preprocessing
#     * [4.1](#4_1): Outliers
#     * [4.2](#4_2): Missing values
#     * [4.3](#4_3): Encoding
#     * [4.4](#4_4): Scaling
#     * [4.5](#4_5): Splitting
# <br />
# <br />
# * [Part 5](#part5): Model training
# * [Part 6](#part6): Performance evaluation
# * [Part 7](#part7): Feature importance and statistical tests
# * [Part 8](#part8): Converting the output
# * [Part 9](#part9): Pipeline creation

# %% [markdown]
# ## Notebook Setup

# %%
#Essentials
import pandas as pd
from pandas import Series, DataFrame
from pandas.api.types import CategoricalDtype
pd.options.display.max_columns = None
import numpy as np; np.random.seed(2022)
import random
import sqlite3
import pyodbc

#Image creation and display
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.patches as mpatches
from matplotlib import pyplot
import plotly.express as px
import plotly.graph_objects as go
#from image import image, display

#Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline

#Models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.base import clone
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import BaggingClassifier

#Other
import itertools as it
import io
import os
os.sys.path
import sys
import glob
import concurrent.futures
from __future__ import print_function
import binascii
import struct
from PIL import Image
import scipy
import scipy.misc
import scipy.cluster
import datetime, time
import functools, operator
from datetime import datetime

# %%
df = pd.read_csv('flat.csv')
df.describe()
# Out:
# c:\Users\MarfaPopova\S2R Analytics\Development & Support Team - Power BI for Synergy - Advanced Analytics\DataFlowExtract\venv\lib\site-packages\IPython\core\interactiveshell.py:3398: DtypeWarning: Columns (6,7,17,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          Project_ID  Project_Size_Sort_Order  Total_Num_Stages  \
# count  5.059350e+05            505934.000000     468061.000000
# mean   5.647774e+05                 6.240108         21.362560
# std    2.682577e+05                 1.871434         23.261015
# min    3.677040e+05                 1.000000          1.000000
# 25%    3.719740e+05                 5.000000          6.000000
# 50%    3.763890e+05                 7.000000         13.000000
# 75%    7.263650e+05                 8.000000         29.000000
# max    1.567895e+06                 8.000000        133.000000
#
#        Perc_of_Stages_with_Fixed_Fee  Project_Manager  \
# count                  468061.000000     5.002410e+05
# mean                       72.484925     7.686244e+06
# std                        27.357930     3.089861e+05
# min                         1.920000     7.612683e+06
# 25%                        57.140000     7.612773e+06
# 50%                        80.000000     7.612882e+06
# 75%                        96.240000     7.613028e+06
# max                       100.000000     1.009472e+07
#
#        Employment_Total_Months  Perc_of_Subcontractors  \
# count            500241.000000           505088.000000
# mean                135.674021                0.029376
# std                  99.065004                0.183591
# min                  -4.000000                0.000000
# 25%                  57.000000                0.000000
# 50%                 117.000000                0.000000
# 75%                 190.000000                0.000000
# max                 436.000000               50.000000
#
#        Project_Duration_Weeks  Total_Data_Issues     Client_ID  \
# count           499957.000000      505932.000000  1.520040e+05
# mean               109.890273          13.810490  8.111726e+06
# std                 91.858582          18.054033  7.926905e+05
# min                  0.000000           0.000000  7.613244e+06
# 25%                 46.000000           4.000000  7.616861e+06
# 50%                 91.000000           9.000000  7.622639e+06
# 75%                136.000000          17.000000  8.698505e+06
# max                584.000000         143.000000  1.031480e+07
#
#        Client_Projects_Total_No  Client_Duration_Months      Stage_ID  \
# count             152004.000000           152004.000000  5.002040e+05
# mean                   4.923055               65.598892  2.710968e+06
# std                   10.214084               51.908373  1.313294e+06
# min                    1.000000                1.000000  1.388262e+06
# 25%                    1.000000               19.000000  1.426588e+06
# 50%                    2.000000               49.000000  2.315372e+06
# 75%                    3.000000              116.000000  3.706600e+06
# max                  195.000000              149.000000  6.014965e+06
#
#        Stage_Duration_Weeks  Recoverability  Profit_Measure
# count         500204.000000   488242.000000   479475.000000
# mean              38.356587        1.646284        1.148097
# std              105.084383        0.345200        0.858805
# min            -4697.000000        0.677418        0.000000
# 25%                4.000000        1.389992        0.360029
# 50%               27.000000        1.615248        1.245257
# 75%               56.000000        1.877431        1.688814
# max              494.000000        2.651113        4.264392

# %% [markdown]
# ## Part 3: <a class="anchor" id="part3"></a> Preprocessing

# %% [markdown]
# ### 3.1 <a class="anchor" id="3_1"></a> Outliers

# %%
for x in ['Recoverability']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan

    df.loc[df[x] > max,x] = np.nan

df.boxplot('Recoverability')
# Out:
# <AxesSubplot:>

# %%
for x in ['Profit_Measure']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan

    df.loc[df[x] > max,x] = np.nan

df.boxplot('Profit_Measure')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Interpretation: https://www.mathbootcamps.com/how-to-read-a-boxplot/

# %% [markdown]
# ### 3.2 <a class="anchor" id="3_2"></a> Missing values

# %%
df
# Out:
#         Project_ID    Country          Office                         Sector  \
# 0         367704.0  Australia         Whyalla                 Ports & Marine
# 1         367704.0  Australia         Whyalla                 Ports & Marine
# 2         367704.0  Australia         Whyalla                 Ports & Marine
# 3         367704.0  Australia         Whyalla                 Ports & Marine
# 4         367704.0  Australia         Whyalla                 Ports & Marine
# ...            ...        ...             ...                            ...
# 505930   1529864.0  Australia   WGAWA Pty Ltd    Civic & Education Buildings
# 505931   1529864.0  Australia   WGAWA Pty Ltd    Civic & Education Buildings
# 505932   1538446.0  Australia  WGAVIC Pty Ltd                         Energy
# 505933   1538447.0  Australia  WGAVIC Pty Ltd                         Energy
# 505934   1567895.0  Australia   WGASA Pty Ltd  Commercial & Retail Buildings
#
#         Project_Size_Sort_Order  Total_Num_Stages Is_Multi_Discipline_Project  \
# 0                           4.0               1.0                       False
# 1                           4.0               1.0                       False
# 2                           4.0               1.0                       False
# 3                           4.0               1.0                       False
# 4                           4.0               1.0                       False
# ...                         ...               ...                         ...
# 505930                      1.0               2.0                       False
# 505931                      1.0               2.0                       False
# 505932                      1.0               1.0                       False
# 505933                      1.0               1.0                       False
# 505934                      NaN               NaN                         NaN
#
#        Is_First_Client_Project                     Default_Rate_Group  \
# 0                         True                               Standard
# 1                         True                               Standard
# 2                         True                               Standard
# 3                         True                               Standard
# 4                         True                               Standard
# ...                        ...                                    ...
# 505930                   False  WA Chargeout Rates from 1st July 2021
# 505931                   False  WA Chargeout Rates from 1st July 2021
# 505932                   False                     Vic chargeout FY22
# 505933                   False                     Vic chargeout FY22
# 505934                     NaN           SA June 2021 Chargeout Rates
#
#         Perc_of_Stages_with_Fixed_Fee       Project_Director  Project_Manager  \
# 0                               100.0           Mark Gilbert        7612852.0
# 1                               100.0           Mark Gilbert        7612852.0
# 2                               100.0           Mark Gilbert        7612852.0
# 3                               100.0           Mark Gilbert        7612852.0
# 4                               100.0           Mark Gilbert        7612852.0
# ...                               ...                    ...              ...
# 505930                           50.0         James Davidson        7809410.0
# 505931                           50.0         James Davidson        7809410.0
# 505932                          100.0  Cameron Jackson (MPD)        7612860.0
# 505933                          100.0  Cameron Jackson (MPD)        7612860.0
# 505934                            NaN       Nick Lelos (MPD)        7612773.0
#
#            Synergy_Team  Employment_Total_Months Manager_Is_Recent  \
# 0       SA - Industrial                    117.0             False
# 1       SA - Industrial                    117.0             False
# 2       SA - Industrial                    117.0             False
# 3       SA - Industrial                    117.0             False
# 4       SA - Industrial                    117.0             False
# ...                 ...                      ...               ...
# 505930       WA - Civil                     20.0             False
# 505931       WA - Civil                     20.0             False
# 505932  VIC - Buildings                    171.0             False
# 505933  VIC - Buildings                    171.0             False
# 505934   SA - Buildings                    310.0             False
#
#         Perc_of_Subcontractors  Project_Duration_Weeks Is_Front_Loaded  \
# 0                          0.0                     4.0            True
# 1                          0.0                     4.0            True
# 2                          0.0                     4.0            True
# 3                          0.0                     4.0            True
# 4                          0.0                     4.0            True
# ...                        ...                     ...             ...
# 505930                     NaN                     1.0             NaN
# 505931                     NaN                     1.0             NaN
# 505932                     NaN                     3.0             NaN
# 505933                     NaN                     4.0             NaN
# 505934                     NaN                     NaN             NaN
#
#        Delivered_on_Time  Fully_In_Lockdown  Partially_In_Lockdown  \
# 0                    NaN              False                  False
# 1                    NaN              False                  False
# 2                    NaN              False                  False
# 3                    NaN              False                  False
# 4                    NaN              False                  False
# ...                  ...                ...                    ...
# 505930               NaN              False                  False
# 505931               NaN              False                  False
# 505932              True              False                  False
# 505933              True              False                  False
# 505934              True              False                  False
#
#        Suffered_Data_Loss  Total_Data_Issues  Client_ID  \
# 0                   False                2.0  7615441.0
# 1                   False                2.0  7615441.0
# 2                   False                2.0  7615441.0
# 3                   False                2.0  7615441.0
# 4                   False                2.0  7615441.0
# ...                   ...                ...        ...
# 505930              False                1.0        NaN
# 505931              False                1.0        NaN
# 505932              False                0.0        NaN
# 505933              False                1.0        NaN
# 505934              False                NaN        NaN
#
#         Client_Projects_Total_No Client_Is_Repeated  Client_Duration_Months  \
# 0                            6.0               True                   146.0
# 1                            6.0               True                   146.0
# 2                            6.0               True                   146.0
# 3                            6.0               True                   146.0
# 4                            6.0               True                   146.0
# ...                          ...                ...                     ...
# 505930                       NaN                NaN                     NaN
# 505931                       NaN                NaN                     NaN
# 505932                       NaN                NaN                     NaN
# 505933                       NaN                NaN                     NaN
# 505934                       NaN                NaN                     NaN
#
#        Client_Is_Recent   Stage_ID Stage_Discipline  Stage_Duration_Weeks  \
# 0                 False  1388262.0           Design                   0.0
# 1                 False  1388262.0           Design                   0.0
# 2                 False  1388262.0           Design                   0.0
# 3                 False  1388262.0           Design                   0.0
# 4                 False  1388262.0           Design                   0.0
# ...                 ...        ...              ...                   ...
# 505930              NaN  5998563.0        * NOT SET                   5.0
# 505931              NaN  5998564.0        * NOT SET                   5.0
# 505932              NaN  6009400.0        * NOT SET                  15.0
# 505933              NaN  6009401.0        * NOT SET                  16.0
# 505934              NaN        NaN              NaN                   NaN
#
#         Recoverability  Profit_Measure
# 0             2.424242        0.000000
# 1             2.424242        0.000000
# 2             2.424242        0.000000
# 3             1.843658        1.284239
# 4             1.728429        1.203816
# ...                ...             ...
# 505930             NaN             NaN
# 505931             NaN             NaN
# 505932             NaN             NaN
# 505933             NaN             NaN
# 505934             NaN             NaN
#
# [505935 rows x 33 columns]

# %%
stage_lvl = pd.DataFrame(df.groupby(['Project_ID', 'Stage_ID'])['Recoverability', 'Profit_Measure'].sum()).reset_index()
stage_lvl
# Out:
# C:\Users\MarfaPopova\AppData\Local\Temp\ipykernel_14612\2231829664.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_grouped = pd.DataFrame(df.groupby(['Project_ID', 'Stage_ID'])['Recoverability', 'Profit_Measure'].sum()).reset_index()
#        Project_ID   Stage_ID  Recoverability  Profit_Measure
# 0        367704.0  1388262.0       70.089817       57.019199
# 1        367711.0  1388295.0       16.655101       16.655101
# 2        367711.0  1388296.0       60.293234       24.276015
# 3        367711.0  2096626.0       12.451831       12.451831
# 4        367711.0  4063518.0        6.338760        7.362404
# ...           ...        ...             ...             ...
# 21408   1524776.0  6014965.0        0.000000        0.000000
# 21409   1529864.0  5998563.0        0.000000        0.000000
# 21410   1529864.0  5998564.0        0.000000        0.000000
# 21411   1538446.0  6009400.0        0.000000        0.000000
# 21412   1538447.0  6009401.0        0.000000        0.000000
#
# [21413 rows x 4 columns]

# %%
project_lvl = pd.DataFrame(df.groupby(['Project_ID'])['Recoverability', 'Profit_Measure'].sum()).reset_index()
project_lvl
# Out:
# C:\Users\MarfaPopova\AppData\Local\Temp\ipykernel_14612\2321089568.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   project_lvl = pd.DataFrame(df.groupby(['Project_ID'])['Recoverability', 'Profit_Measure'].sum()).reset_index()
#       Project_ID  Recoverability  Profit_Measure
# 0       367704.0       70.089817       57.019199
# 1       367705.0        0.000000        0.000000
# 2       367706.0        0.000000        0.000000
# 3       367707.0        0.000000        0.000000
# 4       367708.0        0.000000        0.000000
# ...          ...             ...             ...
# 9750   1524776.0        0.000000        0.000000
# 9751   1529864.0        0.000000        0.000000
# 9752   1538446.0        0.000000        0.000000
# 9753   1538447.0        0.000000        0.000000
# 9754   1567895.0        0.000000        0.000000
#
# [9755 rows x 3 columns]

# %%
df_grouped['Recoverability'].value_counts()
# Out:
# 0.000000       5995
# 4.607823         25
# 6.143764         21
# 7.679705         14
# 10.751587        11
#                ...
# 11.111749         1
# 1992.148048       1
# 59.705823         1
# 568.378120        1
# 1.439539          1
# Name: Recoverability, Length: 3555, dtype: int64

# %%
df_grouped['Profit_Measure'].value_counts()
# Out:
# 0.000000       6267
# 2.702815          4
# 4.607823          4
# 4.151100          3
# 4.710219          3
#                ...
# 46.497626         1
# 2081.157165       1
# 60.910573         1
# 1046.129354       1
# 2.423949          1
# Name: Profit_Measure, Length: 3451, dtype: int64

# %%
# Number of columns having null values in the old dataset
cols = df.columns[df.isnull().any()].to_list()

for c in cols:
    print(c, df[c].isnull().sum())
# Out:
# Country 12731
# Project_Size_Sort_Order 1
# Total_Num_Stages 37874
# Is_Multi_Discipline_Project 1
# Is_First_Client_Project 1
# Perc_of_Stages_with_Fixed_Fee 37874
# Project_Director 1
# Project_Manager 5694
# Synergy_Team 5694
# Employment_Total_Months 5694
# Manager_Is_Recent 11048
# Perc_of_Subcontractors 847
# Project_Duration_Weeks 5978
# Is_Front_Loaded 512
# Delivered_on_Time 324536
# Suffered_Data_Loss 5719
# Total_Data_Issues 3
# Client_ID 353931
# Client_Projects_Total_No 353931
# Client_Is_Repeated 353931
# Client_Duration_Months 353931
# Client_Is_Recent 353931
# Stage_ID 5731
# Stage_Discipline 5731
# Stage_Duration_Weeks 5731
# Recoverability 17693
# Profit_Measure 26460

# %% [markdown]
# ### 3.3 <a class="anchor" id="3_3"></a> Feature engineering

# %% [markdown]
# ### 3.3 <a class="anchor" id="3_3"></a> Encoding

# %% [markdown]
# ### 3.4 <a class="anchor" id="3_4"></a> Scaling

# %% [markdown]
# ### 3.5 <a class="anchor" id="3_5"></a> Splitting

# %% [markdown]
# ## Part 4: <a class="anchor" id="part4"></a> Exploratory data analysis
